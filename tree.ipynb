# %%
# %pip install treelib anytree gym matplotlib
# Out:
# Requirement already satisfied: treelib in /home/jordy/miniconda3/lib/python3.9/site-packages (1.6.1)
# Requirement already satisfied: anytree in /home/jordy/miniconda3/lib/python3.9/site-packages (2.8.0)
# Requirement already satisfied: gym in /home/jordy/miniconda3/lib/python3.9/site-packages (0.21.0)
# Requirement already satisfied: six>=1.9.0 in /home/jordy/miniconda3/lib/python3.9/site-packages (from anytree) (1.15.0)
# Requirement already satisfied: numpy>=1.18.0 in /home/jordy/miniconda3/lib/python3.9/site-packages (from gym) (1.19.5)
# Requirement already satisfied: cloudpickle>=1.2.0 in /home/jordy/miniconda3/lib/python3.9/site-packages (from gym) (2.0.0)
# Collecting matplotlib
#   Downloading matplotlib-3.5.1-cp39-cp39-manylinux_2_5_x86_64.manylinux1_x86_64.whl (11.2 MB)
#      |████████████████████████████████| 11.2 MB 5.0 MB/s eta 0:00:01
# Requirement already satisfied: pyparsing>=2.2.1 in /home/jordy/miniconda3/lib/python3.9/site-packages (from matplotlib) (2.4.7)
# Requirement already satisfied: packaging>=20.0 in /home/jordy/miniconda3/lib/python3.9/site-packages (from matplotlib) (20.9)
# Requirement already satisfied: numpy>=1.18.0 in /home/jordy/miniconda3/lib/python3.9/site-packages (from gym) (1.19.5)
# Requirement already satisfied: python-dateutil>=2.7 in /home/jordy/miniconda3/lib/python3.9/site-packages (from matplotlib) (2.8.1)
# Requirement already satisfied: future in /home/jordy/miniconda3/lib/python3.9/site-packages (from treelib) (0.18.2)
# Collecting cycler>=0.10
#   Downloading cycler-0.11.0-py3-none-any.whl (6.4 kB)
# Collecting fonttools>=4.22.0
#   Downloading fonttools-4.29.1-py3-none-any.whl (895 kB)
#      |████████████████████████████████| 895 kB 22.8 MB/s eta 0:00:01
# Collecting kiwisolver>=1.0.1
#   Downloading kiwisolver-1.3.2-cp39-cp39-manylinux_2_12_x86_64.manylinux2010_x86_64.whl (1.6 MB)
#      |████████████████████████████████| 1.6 MB 25.3 MB/s eta 0:00:01
# Requirement already satisfied: pyparsing>=2.2.1 in /home/jordy/miniconda3/lib/python3.9/site-packages (from matplotlib) (2.4.7)
# Collecting pillow>=6.2.0
#   Downloading Pillow-9.0.1-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (4.3 MB)
#      |████████████████████████████████| 4.3 MB 25.5 MB/s eta 0:00:01
# Requirement already satisfied: six>=1.9.0 in /home/jordy/miniconda3/lib/python3.9/site-packages (from anytree) (1.15.0)
# Installing collected packages: pillow, kiwisolver, fonttools, cycler, matplotlib
# Successfully installed cycler-0.11.0 fonttools-4.29.1 kiwisolver-1.3.2 matplotlib-3.5.1 pillow-9.0.1
# Note: you may need to restart the kernel to use updated packages.

# %%
import sys
from functools import reduce
from treelib import Node, Tree

# %%
sys.path.append('./src')

# %%
from src.playground_env.descriptions import generate_all_descriptions
from src.playground_env.env_params import get_env_params, init_params
from src.playground_env.reward_function import sample_descriptions_from_state, get_reward_from_state
from src.playground_env.env_controller import EnvController

# %%
init_params(
            max_nb_objects = 4,
            admissible_actions = ('Move', 'Grasp', 'Grow', 'Turn', 'Pour'),
            # admissible_attributes=admissible_attributes,
            # furnitures=furnitures,
            # plants=plants,
            # animals=animals
            )
params = get_env_params(render_mode=True)
train, test, extra = generate_all_descriptions(params)

# %%
contagem = "Train: " + str(len(train)) + ", Test: " + str(len(test)) + ", Extra: " + str(len(extra))
display(contagem)
# Out:
# 'Train: 373, Test: 71, Extra: 163'

# %%
by_size = reduce(lambda acc, item: {**acc, len(item): acc.get(len(item), list()) + [item]}, [g.split(" ") for g in train], {})

# %%
by_size
# Out:
# {2: [['Go', 'bottom'],
#   ['Go', 'center'],
#   ['Go', 'left'],
#   ['Go', 'right'],
#   ['Go', 'top']],
#  3: [['Go', 'bottom', 'left'],
#   ['Go', 'bottom', 'right'],
#   ['Go', 'top', 'left'],
#   ['Go', 'top', 'right'],
#   ['Grasp', 'any', 'algae'],
#   ['Grasp', 'any', 'bonsai'],
#   ['Grasp', 'any', 'bush'],
#   ['Grasp', 'any', 'cactus'],
#   ['Grasp', 'any', 'carnivorous'],
#   ['Grasp', 'any', 'carpet'],
#   ['Grasp', 'any', 'cat'],
#   ['Grasp', 'any', 'chair'],
#   ['Grasp', 'any', 'chameleon'],
#   ['Grasp', 'any', 'cow'],
#   ['Grasp', 'any', 'cupboard'],
#   ['Grasp', 'any', 'desk'],
#   ['Grasp', 'any', 'dog'],
#   ['Grasp', 'any', 'door'],
#   ['Grasp', 'any', 'env_objects'],
#   ['Grasp', 'any', 'food'],
#   ['Grasp', 'any', 'furniture'],
#   ['Grasp', 'any', 'grass'],
#   ['Grasp', 'any', 'human'],
#   ['Grasp', 'any', 'lamp'],
#   ['Grasp', 'any', 'light'],
#   ['Grasp', 'any', 'lion'],
#   ['Grasp', 'any', 'living_thing'],
#   ['Grasp', 'any', 'mouse'],
#   ['Grasp', 'any', 'parrot'],
#   ['Grasp', 'any', 'pig'],
#   ['Grasp', 'any', 'plant'],
#   ['Grasp', 'any', 'rose'],
#   ['Grasp', 'any', 'sink'],
#   ['Grasp', 'any', 'sofa'],
#   ['Grasp', 'any', 'supply'],
#   ['Grasp', 'any', 'table'],
#   ['Grasp', 'any', 'tea'],
#   ['Grasp', 'any', 'thing'],
#   ['Grasp', 'any', 'tree'],
#   ['Grasp', 'any', 'water'],
#   ['Grasp', 'any', 'window'],
#   ['Grasp', 'blue', 'algae'],
#   ['Grasp', 'blue', 'bonsai'],
#   ['Grasp', 'blue', 'bush'],
#   ['Grasp', 'blue', 'cactus'],
#   ['Grasp', 'blue', 'carnivorous'],
#   ['Grasp', 'blue', 'carpet'],
#   ['Grasp', 'blue', 'cat'],
#   ['Grasp', 'blue', 'chair'],
#   ['Grasp', 'blue', 'chameleon'],
#   ['Grasp', 'blue', 'cow'],
#   ['Grasp', 'blue', 'cupboard'],
#   ['Grasp', 'blue', 'desk'],
#   ['Grasp', 'blue', 'dog'],
#   ['Grasp', 'blue', 'env_objects'],
#   ['Grasp', 'blue', 'food'],
#   ['Grasp', 'blue', 'furniture'],
#   ['Grasp', 'blue', 'grass'],
#   ['Grasp', 'blue', 'human'],
#   ['Grasp', 'blue', 'lamp'],
#   ['Grasp', 'blue', 'light'],
#   ['Grasp', 'blue', 'lion'],
#   ['Grasp', 'blue', 'living_thing'],
#   ['Grasp', 'blue', 'mouse'],
#   ['Grasp', 'blue', 'parrot'],
#   ['Grasp', 'blue', 'pig'],
#   ['Grasp', 'blue', 'plant'],
#   ['Grasp', 'blue', 'rose'],
#   ['Grasp', 'blue', 'sink'],
#   ['Grasp', 'blue', 'sofa'],
#   ['Grasp', 'blue', 'supply'],
#   ['Grasp', 'blue', 'table'],
#   ['Grasp', 'blue', 'tea'],
#   ['Grasp', 'blue', 'thing'],
#   ['Grasp', 'blue', 'tree'],
#   ['Grasp', 'blue', 'water'],
#   ['Grasp', 'blue', 'window'],
#   ['Grasp', 'green', 'algae'],
#   ['Grasp', 'green', 'bonsai'],
#   ['Grasp', 'green', 'bush'],
#   ['Grasp', 'green', 'cactus'],
#   ['Grasp', 'green', 'carnivorous'],
#   ['Grasp', 'green', 'carpet'],
#   ['Grasp', 'green', 'cat'],
#   ['Grasp', 'green', 'chair'],
#   ['Grasp', 'green', 'chameleon'],
#   ['Grasp', 'green', 'cow'],
#   ['Grasp', 'green', 'cupboard'],
#   ['Grasp', 'green', 'desk'],
#   ['Grasp', 'green', 'door'],
#   ['Grasp', 'green', 'env_objects'],
#   ['Grasp', 'green', 'food'],
#   ['Grasp', 'green', 'furniture'],
#   ['Grasp', 'green', 'grass'],
#   ['Grasp', 'green', 'human'],
#   ['Grasp', 'green', 'lamp'],
#   ['Grasp', 'green', 'light'],
#   ['Grasp', 'green', 'lion'],
#   ['Grasp', 'green', 'living_thing'],
#   ['Grasp', 'green', 'mouse'],
#   ['Grasp', 'green', 'parrot'],
#   ['Grasp', 'green', 'pig'],
#   ['Grasp', 'green', 'plant'],
#   ['Grasp', 'green', 'rose'],
#   ['Grasp', 'green', 'sink'],
#   ['Grasp', 'green', 'sofa'],
#   ['Grasp', 'green', 'supply'],
#   ['Grasp', 'green', 'table'],
#   ['Grasp', 'green', 'tea'],
#   ['Grasp', 'green', 'thing'],
#   ['Grasp', 'green', 'tree'],
#   ['Grasp', 'green', 'water'],
#   ['Grasp', 'green', 'window'],
#   ['Grasp', 'red', 'algae'],
#   ['Grasp', 'red', 'bonsai'],
#   ['Grasp', 'red', 'bush'],
#   ['Grasp', 'red', 'cactus'],
#   ['Grasp', 'red', 'carnivorous'],
#   ['Grasp', 'red', 'carpet'],
#   ['Grasp', 'red', 'cat'],
#   ['Grasp', 'red', 'chair'],
#   ['Grasp', 'red', 'chameleon'],
#   ['Grasp', 'red', 'cow'],
#   ['Grasp', 'red', 'cupboard'],
#   ['Grasp', 'red', 'desk'],
#   ['Grasp', 'red', 'dog'],
#   ['Grasp', 'red', 'door'],
#   ['Grasp', 'red', 'env_objects'],
#   ['Grasp', 'red', 'food'],
#   ['Grasp', 'red', 'furniture'],
#   ['Grasp', 'red', 'grass'],
#   ['Grasp', 'red', 'human'],
#   ['Grasp', 'red', 'lamp'],
#   ['Grasp', 'red', 'light'],
#   ['Grasp', 'red', 'lion'],
#   ['Grasp', 'red', 'living_thing'],
#   ['Grasp', 'red', 'mouse'],
#   ['Grasp', 'red', 'parrot'],
#   ['Grasp', 'red', 'pig'],
#   ['Grasp', 'red', 'plant'],
#   ['Grasp', 'red', 'rose'],
#   ['Grasp', 'red', 'sink'],
#   ['Grasp', 'red', 'sofa'],
#   ['Grasp', 'red', 'supply'],
#   ['Grasp', 'red', 'table'],
#   ['Grasp', 'red', 'tea'],
#   ['Grasp', 'red', 'thing'],
#   ['Grasp', 'red', 'water'],
#   ['Grasp', 'red', 'window'],
#   ['Grow', 'any', 'animal'],
#   ['Grow', 'any', 'cat'],
#   ['Grow', 'any', 'chameleon'],
#   ['Grow', 'any', 'cow'],
#   ['Grow', 'any', 'dog'],
#   ['Grow', 'any', 'env_objects'],
#   ['Grow', 'any', 'fly'],
#   ['Grow', 'any', 'human'],
#   ['Grow', 'any', 'light'],
#   ['Grow', 'any', 'lion'],
#   ['Grow', 'any', 'mouse'],
#   ['Grow', 'any', 'parrot'],
#   ['Grow', 'any', 'pig'],
#   ['Grow', 'any', 'thing'],
#   ['Grow', 'blue', 'animal'],
#   ['Grow', 'blue', 'cat'],
#   ['Grow', 'blue', 'chameleon'],
#   ['Grow', 'blue', 'cow'],
#   ['Grow', 'blue', 'dog'],
#   ['Grow', 'blue', 'env_objects'],
#   ['Grow', 'blue', 'fly'],
#   ['Grow', 'blue', 'human'],
#   ['Grow', 'blue', 'light'],
#   ['Grow', 'blue', 'lion'],
#   ['Grow', 'blue', 'mouse'],
#   ['Grow', 'blue', 'parrot'],
#   ['Grow', 'blue', 'pig'],
#   ['Grow', 'blue', 'thing'],
#   ['Grow', 'green', 'animal'],
#   ['Grow', 'green', 'cat'],
#   ['Grow', 'green', 'chameleon'],
#   ['Grow', 'green', 'cow'],
#   ['Grow', 'green', 'env_objects'],
#   ['Grow', 'green', 'fly'],
#   ['Grow', 'green', 'human'],
#   ['Grow', 'green', 'light'],
#   ['Grow', 'green', 'lion'],
#   ['Grow', 'green', 'mouse'],
#   ['Grow', 'green', 'parrot'],
#   ['Grow', 'green', 'pig'],
#   ['Grow', 'green', 'thing'],
#   ['Grow', 'red', 'animal'],
#   ['Grow', 'red', 'cat'],
#   ['Grow', 'red', 'chameleon'],
#   ['Grow', 'red', 'cow'],
#   ['Grow', 'red', 'dog'],
#   ['Grow', 'red', 'env_objects'],
#   ['Grow', 'red', 'fly'],
#   ['Grow', 'red', 'human'],
#   ['Grow', 'red', 'light'],
#   ['Grow', 'red', 'lion'],
#   ['Grow', 'red', 'mouse'],
#   ['Grow', 'red', 'parrot'],
#   ['Grow', 'red', 'pig'],
#   ['Grow', 'red', 'thing'],
#   ['Pour', 'any', 'algae'],
#   ['Pour', 'any', 'animal'],
#   ['Pour', 'any', 'bonsai'],
#   ['Pour', 'any', 'bush'],
#   ['Pour', 'any', 'cactus'],
#   ['Pour', 'any', 'carnivorous'],
#   ['Pour', 'any', 'carpet'],
#   ['Pour', 'any', 'cat'],
#   ['Pour', 'any', 'chair'],
#   ['Pour', 'any', 'chameleon'],
#   ['Pour', 'any', 'cow'],
#   ['Pour', 'any', 'cupboard'],
#   ['Pour', 'any', 'desk'],
#   ['Pour', 'any', 'dog'],
#   ['Pour', 'any', 'door'],
#   ['Pour', 'any', 'env_objects'],
#   ['Pour', 'any', 'fly'],
#   ['Pour', 'any', 'food'],
#   ['Pour', 'any', 'furniture'],
#   ['Pour', 'any', 'grass'],
#   ['Pour', 'any', 'human'],
#   ['Pour', 'any', 'lamp'],
#   ['Pour', 'any', 'light'],
#   ['Pour', 'any', 'lion'],
#   ['Pour', 'any', 'living_thing'],
#   ['Pour', 'any', 'mouse'],
#   ['Pour', 'any', 'parrot'],
#   ['Pour', 'any', 'pig'],
#   ['Pour', 'any', 'plant'],
#   ['Pour', 'any', 'rose'],
#   ['Pour', 'any', 'sink'],
#   ['Pour', 'any', 'sofa'],
#   ['Pour', 'any', 'supply'],
#   ['Pour', 'any', 'table'],
#   ['Pour', 'any', 'tea'],
#   ['Pour', 'any', 'thing'],
#   ['Pour', 'any', 'tree'],
#   ['Pour', 'any', 'water'],
#   ['Pour', 'any', 'window'],
#   ['Pour', 'blue', 'algae'],
#   ['Pour', 'blue', 'animal'],
#   ['Pour', 'blue', 'bonsai'],
#   ['Pour', 'blue', 'bush'],
#   ['Pour', 'blue', 'cactus'],
#   ['Pour', 'blue', 'carnivorous'],
#   ['Pour', 'blue', 'carpet'],
#   ['Pour', 'blue', 'cat'],
#   ['Pour', 'blue', 'chair'],
#   ['Pour', 'blue', 'chameleon'],
#   ['Pour', 'blue', 'cow'],
#   ['Pour', 'blue', 'cupboard'],
#   ['Pour', 'blue', 'desk'],
#   ['Pour', 'blue', 'dog'],
#   ['Pour', 'blue', 'env_objects'],
#   ['Pour', 'blue', 'fly'],
#   ['Pour', 'blue', 'food'],
#   ['Pour', 'blue', 'furniture'],
#   ['Pour', 'blue', 'grass'],
#   ['Pour', 'blue', 'human'],
#   ['Pour', 'blue', 'lamp'],
#   ['Pour', 'blue', 'light'],
#   ['Pour', 'blue', 'lion'],
#   ['Pour', 'blue', 'living_thing'],
#   ['Pour', 'blue', 'mouse'],
#   ['Pour', 'blue', 'parrot'],
#   ['Pour', 'blue', 'pig'],
#   ['Pour', 'blue', 'plant'],
#   ['Pour', 'blue', 'rose'],
#   ['Pour', 'blue', 'sink'],
#   ['Pour', 'blue', 'sofa'],
#   ['Pour', 'blue', 'supply'],
#   ['Pour', 'blue', 'table'],
#   ['Pour', 'blue', 'tea'],
#   ['Pour', 'blue', 'thing'],
#   ['Pour', 'blue', 'tree'],
#   ['Pour', 'blue', 'water'],
#   ['Pour', 'blue', 'window'],
#   ['Pour', 'green', 'algae'],
#   ['Pour', 'green', 'animal'],
#   ['Pour', 'green', 'bonsai'],
#   ['Pour', 'green', 'bush'],
#   ['Pour', 'green', 'cactus'],
#   ['Pour', 'green', 'carnivorous'],
#   ['Pour', 'green', 'carpet'],
#   ['Pour', 'green', 'cat'],
#   ['Pour', 'green', 'chair'],
#   ['Pour', 'green', 'chameleon'],
#   ['Pour', 'green', 'cow'],
#   ['Pour', 'green', 'cupboard'],
#   ['Pour', 'green', 'desk'],
#   ['Pour', 'green', 'door'],
#   ['Pour', 'green', 'env_objects'],
#   ['Pour', 'green', 'fly'],
#   ['Pour', 'green', 'food'],
#   ['Pour', 'green', 'furniture'],
#   ['Pour', 'green', 'grass'],
#   ['Pour', 'green', 'human'],
#   ['Pour', 'green', 'lamp'],
#   ['Pour', 'green', 'light'],
#   ['Pour', 'green', 'lion'],
#   ['Pour', 'green', 'living_thing'],
#   ['Pour', 'green', 'mouse'],
#   ['Pour', 'green', 'parrot'],
#   ['Pour', 'green', 'pig'],
#   ['Pour', 'green', 'plant'],
#   ['Pour', 'green', 'rose'],
#   ['Pour', 'green', 'sink'],
#   ['Pour', 'green', 'sofa'],
#   ['Pour', 'green', 'supply'],
#   ['Pour', 'green', 'table'],
#   ['Pour', 'green', 'tea'],
#   ['Pour', 'green', 'thing'],
#   ['Pour', 'green', 'tree'],
#   ['Pour', 'green', 'water'],
#   ['Pour', 'green', 'window'],
#   ['Pour', 'red', 'algae'],
#   ['Pour', 'red', 'animal'],
#   ['Pour', 'red', 'bonsai'],
#   ['Pour', 'red', 'bush'],
#   ['Pour', 'red', 'cactus'],
#   ['Pour', 'red', 'carnivorous'],
#   ['Pour', 'red', 'carpet'],
#   ['Pour', 'red', 'cat'],
#   ['Pour', 'red', 'chair'],
#   ['Pour', 'red', 'chameleon'],
#   ['Pour', 'red', 'cow'],
#   ['Pour', 'red', 'cupboard'],
#   ['Pour', 'red', 'desk'],
#   ['Pour', 'red', 'dog'],
#   ['Pour', 'red', 'door'],
#   ['Pour', 'red', 'env_objects'],
#   ['Pour', 'red', 'fly'],
#   ['Pour', 'red', 'food'],
#   ['Pour', 'red', 'furniture'],
#   ['Pour', 'red', 'grass'],
#   ['Pour', 'red', 'human'],
#   ['Pour', 'red', 'lamp'],
#   ['Pour', 'red', 'light'],
#   ['Pour', 'red', 'lion'],
#   ['Pour', 'red', 'living_thing'],
#   ['Pour', 'red', 'mouse'],
#   ['Pour', 'red', 'parrot'],
#   ['Pour', 'red', 'pig'],
#   ['Pour', 'red', 'plant'],
#   ['Pour', 'red', 'rose'],
#   ['Pour', 'red', 'sink'],
#   ['Pour', 'red', 'sofa'],
#   ['Pour', 'red', 'supply'],
#   ['Pour', 'red', 'table'],
#   ['Pour', 'red', 'tea'],
#   ['Pour', 'red', 'thing'],
#   ['Pour', 'red', 'water'],
#   ['Pour', 'red', 'window'],
#   ['Turn', 'off', 'light'],
#   ['Turn', 'on', 'light']],
#  4: [['Grasp', 'any', 'blue', 'thing'],
#   ['Grasp', 'any', 'green', 'thing'],
#   ['Grasp', 'any', 'red', 'thing'],
#   ['Grow', 'any', 'blue', 'thing'],
#   ['Grow', 'any', 'green', 'thing'],
#   ['Grow', 'any', 'red', 'thing'],
#   ['Pour', 'any', 'blue', 'thing'],
#   ['Pour', 'any', 'green', 'thing'],
#   ['Pour', 'any', 'red', 'thing']]}

# %%
class Metrics:
    competence:float
    novelty:float

    def __init__(self, competence:float=0.0, novelty:float=0.0):
        self.competence = competence
        self.novelty = novelty

    def update_novelty(self, novelty):
        self.novelty = novelty

    def update_competence(self, competence):
        self.competence = competence

# %%
import random
tree = Tree()

tree.create_node('root', 'root', data=Metrics(random.random(), random.random()))
for s, goals in by_size.items():
    for g in goals:
        last_node = 'root'
        for i, w in enumerate(g):
            # if i == 0:
            #     id = w
            # else:
            #     id = str(random.random())
            id = w + last_node
            if not tree.contains(id):
                tree.create_node(w, id, parent=last_node, data=Metrics(random.random(), random.random()))
            last_node = id

# %%
tree.show()

# %%
tree.get_node('Goroot').data

# %%
import random
from anytree import Node, RenderTree

node_dict = {}
root = Node('root')
for s, goals in by_size.items():
    for g in goals:
        last_node = root
        for i, w in enumerate(g):
            id = (last_node.name + ' ' if last_node.name != 'root' else '') + w
            if id not in node_dict:
                node_dict[id] = Node(id, parent=last_node)
            last_node = node_dict[id]

# %%
from anytree.exporter import DotExporter

DotExporter(root).to_picture("tree.png")

# %% [markdown]
# <img src="./tree.png">

# %%
DotExporter(root).to_dotfile('tree.dot')
